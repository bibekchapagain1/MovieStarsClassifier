# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/saipallavi.jpg')
img.shape
# Out:
# (1024, 678, 3)

# %%
plt.imshow(img)

# %%
gray
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1148094347.py in <module>
# ----> 1 gray
#
# NameError: name 'gray' is not defined

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1024, 678)

# %%
gray
# Out:
# array([[ 13,  13,  13, ...,  24,  24,  23],
#        [ 13,  13,  13, ...,  25,  24,  24],
#        [ 13,  13,  13, ...,  25,  25,  24],
#        ...,
#        [145,  94,  95, ...,   4,   4,   4],
#        [144,  86,  87, ...,   4,   4,   4],
#        [158,  91,  80, ...,   4,   4,   4]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[128, 194, 326, 326]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (128, 194, 326, 326)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/saipallavi.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/saipallavi.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./test_images/saipallavi1.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/saipallavi1.jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/allu arjun',
#  './dataset/jr ntr',
#  './dataset/kajal aggarwal',
#  './dataset/prabhas',
#  './dataset/sai pallavi',
#  './dataset/salman khan',
#  './dataset/samantha',
#  './dataset/thalapathy vijay']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/allu arjun
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
--RootProject
-img.jpg
-script.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1261775347.py in <module>
# ----> 1 --RootProject
#       2 -img.jpg
#       3 -script.py
#
# NameError: name 'RootProject' is not defined

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       5     celebrity_name = img_dir.split('/')[-1]
#       6     celebrity_file_names_dict[celebrity_name] = []
# ----> 7     for entry in os.scandir(img_dir):
#       8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: './dataset/allu arjun'

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/allu_arjun',
#  './dataset/cropped',
#  './dataset/jr_ntr',
#  './dataset/kajal_aggarwal',
#  './dataset/prabhas',
#  './dataset/sai_pallavi',
#  './dataset/salman_khan',
#  './dataset/samantha',
#  './dataset/thalapathy_vijay']

# %%
img_dirs
# Out:
# ['./dataset/allu_arjun',
#  './dataset/cropped',
#  './dataset/jr_ntr',
#  './dataset/kajal_aggarwal',
#  './dataset/prabhas',
#  './dataset/sai_pallavi',
#  './dataset/salman_khan',
#  './dataset/samantha',
#  './dataset/thalapathy_vijay']

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/allu_arjun',
#  './dataset/jr_ntr',
#  './dataset/kajal_aggarwal',
#  './dataset/prabhas_raju',
#  './dataset/sai_pallavi',
#  './dataset/salman_khan',
#  './dataset/samantha_rutuprabhu',
#  './dataset/thalapathy_vijay']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/allu_arjun
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       5     celebrity_name = img_dir.split('/')[-1]
#       6     celebrity_file_names_dict[celebrity_name] = []
# ----> 7     for entry in os.scandir(img_dir):
#       8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: './dataset/allu_arjun'

# %%
img_dirs
# Out:
# ['./dataset/allu_arjun',
#  './dataset/jr_ntr',
#  './dataset/kajal_aggarwal',
#  './dataset/prabhas_raju',
#  './dataset/sai_pallavi',
#  './dataset/salman_khan',
#  './dataset/samantha_rutuprabhu',
#  './dataset/thalapathy_vijay']

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/sai_pallavi']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/sai_pallavi
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped', './dataset/jr_ntr']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/jr_ntr
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped', './dataset/kajal_aggarwal']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/kajal_aggarwal
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped', './dataset/prabhas_raju']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/prabhas_raju
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped', './dataset/salman_khan']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/salman_khan
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped', './dataset/samantha_rutuprabhu']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/samantha_rutuprabhu
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped', './dataset/thalapathy_vijay']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/thalapathy_vijay
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/thalapathy_vijay
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/anushka_shetty', './dataset/cropped']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/anushka_shetty
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped', './dataset/dhanush']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/dhanush
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped', './dataset/thalapathy_vijay']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/thalapathy_vijay
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped', './dataset/vijay']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/vijay
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped', './dataset/vijay']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/vijay
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
celebrity_file_names_dict
# Out:
# {'cropped': [],
#  'vijay': ['./dataset/cropped/vijay/vijay1.png',
#   './dataset/cropped/vijay/vijay2.png',
#   './dataset/cropped/vijay/vijay3.png',
#   './dataset/cropped/vijay/vijay4.png',
#   './dataset/cropped/vijay/vijay5.png',
#   './dataset/cropped/vijay/vijay6.png',
#   './dataset/cropped/vijay/vijay7.png',
#   './dataset/cropped/vijay/vijay8.png',
#   './dataset/cropped/vijay/vijay9.png',
#   './dataset/cropped/vijay/vijay10.png',
#   './dataset/cropped/vijay/vijay11.png',
#   './dataset/cropped/vijay/vijay12.png',
#   './dataset/cropped/vijay/vijay13.png',
#   './dataset/cropped/vijay/vijay14.png',
#   './dataset/cropped/vijay/vijay15.png',
#   './dataset/cropped/vijay/vijay16.png',
#   './dataset/cropped/vijay/vijay17.png',
#   './dataset/cropped/vijay/vijay18.png',
#   './dataset/cropped/vijay/vijay19.png',
#   './dataset/cropped/vijay/vijay20.png',
#   './dataset/cropped/vijay/vijay21.png',
#   './dataset/cropped/vijay/vijay22.png',
#   './dataset/cropped/vijay/vijay23.png',
#   './dataset/cropped/vijay/vijay24.png',
#   './dataset/cropped/vijay/vijay25.png',
#   './dataset/cropped/vijay/vijay26.png',
#   './dataset/cropped/vijay/vijay27.png',
#   './dataset/cropped/vijay/vijay28.png',
#   './dataset/cropped/vijay/vijay29.png',
#   './dataset/cropped/vijay/vijay30.png',
#   './dataset/cropped/vijay/vijay31.png',
#   './dataset/cropped/vijay/vijay32.png',
#   './dataset/cropped/vijay/vijay33.png',
#   './dataset/cropped/vijay/vijay34.png',
#   './dataset/cropped/vijay/vijay35.png',
#   './dataset/cropped/vijay/vijay36.png',
#   './dataset/cropped/vijay/vijay37.png',
#   './dataset/cropped/vijay/vijay38.png',
#   './dataset/cropped/vijay/vijay39.png']}

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/allu_arjun',
#  './dataset/anushka_shetty',
#  './dataset/cropped',
#  './dataset/dhanush',
#  './dataset/jr_ntr',
#  './dataset/kajal_aggarwal',
#  './dataset/prabhas_raju',
#  './dataset/sai_pallavi',
#  './dataset/salman_khan',
#  './dataset/samantha_rutuprabhu',
#  './dataset/thalapathy_vijay']

# %%
cropped_image_dirs
# Out:
# ['./dataset/cropped/vijay']

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/allu_arjun',
#  './dataset/anushka_shetty',
#  './dataset/cropped',
#  './dataset/dhanush',
#  './dataset/jr_ntr',
#  './dataset/kajal_aggarwal',
#  './dataset/prabhas_raju',
#  './dataset/sai_pallavi',
#  './dataset/salman_khan',
#  './dataset/samantha_rutuprabhu',
#  './dataset/thalapathy_vijay']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/allu_arjun
# Generating cropped images in folder:  ./dataset/cropped/anushka_shetty
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1624354665.py in <module>
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
#      10             cropped_folder = path_to_cr_data + celebrity_name
#
# ~\AppData\Local\Temp/ipykernel_1276/3152581972.py in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
celebrity_file_names_dict
# Out:
# {'allu_arjun': ['./dataset/cropped/allu_arjun/allu_arjun1.png',
#   './dataset/cropped/allu_arjun/allu_arjun2.png',
#   './dataset/cropped/allu_arjun/allu_arjun3.png',
#   './dataset/cropped/allu_arjun/allu_arjun4.png',
#   './dataset/cropped/allu_arjun/allu_arjun5.png',
#   './dataset/cropped/allu_arjun/allu_arjun6.png',
#   './dataset/cropped/allu_arjun/allu_arjun7.png',
#   './dataset/cropped/allu_arjun/allu_arjun8.png',
#   './dataset/cropped/allu_arjun/allu_arjun9.png',
#   './dataset/cropped/allu_arjun/allu_arjun10.png'],
#  'anushka_shetty': ['./dataset/cropped/anushka_shetty/anushka_shetty1.png',
#   './dataset/cropped/anushka_shetty/anushka_shetty2.png',
#   './dataset/cropped/anushka_shetty/anushka_shetty3.png',
#   './dataset/cropped/anushka_shetty/anushka_shetty4.png',
#   './dataset/cropped/anushka_shetty/anushka_shetty5.png',
#   './dataset/cropped/anushka_shetty/anushka_shetty6.png',
#   './dataset/cropped/anushka_shetty/anushka_shetty7.png'],
#  'cropped': []}

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/the_cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/allu_arjun',
#  './dataset/anushka_shetty',
#  './dataset/dhanush',
#  './dataset/jr_ntr',
#  './dataset/kajal_aggarwal',
#  './dataset/prabhas_raju',
#  './dataset/sai_pallavi',
#  './dataset/salman_khan',
#  './dataset/samantha_rutuprabhu',
#  './dataset/thalapathy_vijay']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/the_cropped/allu_arjun
# Generating cropped images in folder:  ./dataset/the_cropped/anushka_shetty
# Generating cropped images in folder:  ./dataset/the_cropped/dhanush
# Generating cropped images in folder:  ./dataset/the_cropped/jr_ntr
# Generating cropped images in folder:  ./dataset/the_cropped/kajal_aggarwal
# Generating cropped images in folder:  ./dataset/the_cropped/prabhas_raju
# Generating cropped images in folder:  ./dataset/the_cropped/sai_pallavi
# Generating cropped images in folder:  ./dataset/the_cropped/salman_khan
# Generating cropped images in folder:  ./dataset/the_cropped/samantha_rutuprabhu
# Generating cropped images in folder:  ./dataset/the_cropped/thalapathy_vijay

# %%
celebrity_file_names_dict
# Out:
# {'allu_arjun': ['./dataset/the_cropped/allu_arjun/allu_arjun1.png',
#   './dataset/the_cropped/allu_arjun/allu_arjun2.png',
#   './dataset/the_cropped/allu_arjun/allu_arjun3.png',
#   './dataset/the_cropped/allu_arjun/allu_arjun4.png',
#   './dataset/the_cropped/allu_arjun/allu_arjun5.png',
#   './dataset/the_cropped/allu_arjun/allu_arjun6.png',
#   './dataset/the_cropped/allu_arjun/allu_arjun7.png',
#   './dataset/the_cropped/allu_arjun/allu_arjun8.png',
#   './dataset/the_cropped/allu_arjun/allu_arjun9.png',
#   './dataset/the_cropped/allu_arjun/allu_arjun10.png'],
#  'anushka_shetty': ['./dataset/the_cropped/anushka_shetty/anushka_shetty1.png',
#   './dataset/the_cropped/anushka_shetty/anushka_shetty2.png',
#   './dataset/the_cropped/anushka_shetty/anushka_shetty3.png',
#   './dataset/the_cropped/anushka_shetty/anushka_shetty4.png',
#   './dataset/the_cropped/anushka_shetty/anushka_shetty5.png',
#   './dataset/the_cropped/anushka_shetty/anushka_shetty6.png',
#   './dataset/the_cropped/anushka_shetty/anushka_shetty7.png'],
#  'dhanush': ['./dataset/the_cropped/dhanush/dhanush1.png',
#   './dataset/the_cropped/dhanush/dhanush2.png',
#   './dataset/the_cropped/dhanush/dhanush3.png',
#   './dataset/the_cropped/dhanush/dhanush4.png',
#   './dataset/the_cropped/dhanush/dhanush5.png',
#   './dataset/the_cropped/dhanush/dhanush6.png',
#   './dataset/the_cropped/dhanush/dhanush7.png',
#   './dataset/the_cropped/dhanush/dhanush8.png',
#   './dataset/the_cropped/dhanush/dhanush9.png',
#   './dataset/the_cropped/dhanush/dhanush10.png',
#   './dataset/the_cropped/dhanush/dhanush11.png',
#   './dataset/the_cropped/dhanush/dhanush12.png',
#   './dataset/the_cropped/dhanush/dhanush13.png',
#   './dataset/the_cropped/dhanush/dhanush14.png',
#   './dataset/the_cropped/dhanush/dhanush15.png',
#   './dataset/the_cropped/dhanush/dhanush16.png',
#   './dataset/the_cropped/dhanush/dhanush17.png',
#   './dataset/the_cropped/dhanush/dhanush18.png'],
#  'jr_ntr': ['./dataset/the_cropped/jr_ntr/jr_ntr1.png',
#   './dataset/the_cropped/jr_ntr/jr_ntr2.png',
#   './dataset/the_cropped/jr_ntr/jr_ntr3.png',
#   './dataset/the_cropped/jr_ntr/jr_ntr4.png',
#   './dataset/the_cropped/jr_ntr/jr_ntr5.png',
#   './dataset/the_cropped/jr_ntr/jr_ntr6.png',
#   './dataset/the_cropped/jr_ntr/jr_ntr7.png',
#   './dataset/the_cropped/jr_ntr/jr_ntr8.png',
#   './dataset/the_cropped/jr_ntr/jr_ntr9.png',
#   './dataset/the_cropped/jr_ntr/jr_ntr10.png',
#   './dataset/the_cropped/jr_ntr/jr_ntr11.png',
#   './dataset/the_cropped/jr_ntr/jr_ntr12.png',
#   './dataset/the_cropped/jr_ntr/jr_ntr13.png',
#   './dataset/the_cropped/jr_ntr/jr_ntr14.png',
#   './dataset/the_cropped/jr_ntr/jr_ntr15.png',
#   './dataset/the_cropped/jr_ntr/jr_ntr16.png',
#   './dataset/the_cropped/jr_ntr/jr_ntr17.png'],
#  'kajal_aggarwal': ['./dataset/the_cropped/kajal_aggarwal/kajal_aggarwal1.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal2.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal3.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal4.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal5.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal6.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal7.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal8.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal9.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal10.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal11.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal12.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal13.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal14.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal15.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal16.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal17.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal18.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal19.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal20.png',
#   './dataset/the_cropped/kajal_aggarwal/kajal_aggarwal21.png'],
#  'prabhas_raju': ['./dataset/the_cropped/prabhas_raju/prabhas_raju1.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju2.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju3.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju4.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju5.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju6.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju7.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju8.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju9.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju10.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju11.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju12.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju13.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju14.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju15.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju16.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju17.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju18.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju19.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju20.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju21.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju22.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju23.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju24.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju25.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju26.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju27.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju28.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju29.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju30.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju31.png',
#   './dataset/the_cropped/prabhas_raju/prabhas_raju32.png'],
#  'sai_pallavi': ['./dataset/the_cropped/sai_pallavi/sai_pallavi1.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi2.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi3.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi4.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi5.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi6.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi7.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi8.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi9.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi10.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi11.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi12.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi13.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi14.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi15.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi16.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi17.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi18.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi19.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi20.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi21.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi22.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi23.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi24.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi25.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi26.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi27.png',
#   './dataset/the_cropped/sai_pallavi/sai_pallavi28.png'],
#  'salman_khan': ['./dataset/the_cropped/salman_khan/salman_khan1.png',
#   './dataset/the_cropped/salman_khan/salman_khan2.png',
#   './dataset/the_cropped/salman_khan/salman_khan3.png',
#   './dataset/the_cropped/salman_khan/salman_khan4.png',
#   './dataset/the_cropped/salman_khan/salman_khan5.png',
#   './dataset/the_cropped/salman_khan/salman_khan6.png',
#   './dataset/the_cropped/salman_khan/salman_khan7.png',
#   './dataset/the_cropped/salman_khan/salman_khan8.png'],
#  'samantha_rutuprabhu': ['./dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu1.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu2.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu3.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu4.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu5.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu6.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu7.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu8.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu9.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu10.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu11.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu12.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu13.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu14.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu15.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu16.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu17.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu18.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu19.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu20.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu21.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu22.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu23.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu24.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu25.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu26.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu27.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu28.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu29.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu30.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu31.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu32.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu33.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu34.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu35.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu36.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu37.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu38.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu39.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu40.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu41.png',
#   './dataset/the_cropped/samantha_rutuprabhu/samantha_rutuprabhu42.png'],
#  'thalapathy_vijay': ['./dataset/the_cropped/thalapathy_vijay/thalapathy_vijay1.png',
#   './dataset/the_cropped/thalapathy_vijay/thalapathy_vijay2.png',
#   './dataset/the_cropped/thalapathy_vijay/thalapathy_vijay3.png',
#   './dataset/the_cropped/thalapathy_vijay/thalapathy_vijay4.png',
#   './dataset/the_cropped/thalapathy_vijay/thalapathy_vijay5.png',
#   './dataset/the_cropped/thalapathy_vijay/thalapathy_vijay6.png',
#   './dataset/the_cropped/thalapathy_vijay/thalapathy_vijay7.png',
#   './dataset/the_cropped/thalapathy_vijay/thalapathy_vijay8.png',
#   './dataset/the_cropped/thalapathy_vijay/thalapathy_vijay9.png',
#   './dataset/the_cropped/thalapathy_vijay/thalapathy_vijay10.png',
#   './dataset/the_cropped/thalapathy_vijay/thalapathy_vijay11.png',
#   './dataset/the_cropped/thalapathy_vijay/thalapathy_vijay12.png',
#   './dataset/the_cropped/thalapathy_vijay/thalapathy_vijay13.png',
#   './dataset/the_cropped/thalapathy_vijay/thalapathy_vijay14.png',
#   './dataset/the_cropped/thalapathy_vijay/thalapathy_vijay15.png',
#   './dataset/the_cropped/thalapathy_vijay/thalapathy_vijay16.png']}

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'allu_arjun': ['./dataset/the_cropped/allu_arjun\\allu_arjun1.png',
#   './dataset/the_cropped/allu_arjun\\allu_arjun10.png',
#   './dataset/the_cropped/allu_arjun\\allu_arjun2.png',
#   './dataset/the_cropped/allu_arjun\\allu_arjun3.png',
#   './dataset/the_cropped/allu_arjun\\allu_arjun4.png',
#   './dataset/the_cropped/allu_arjun\\allu_arjun5.png',
#   './dataset/the_cropped/allu_arjun\\allu_arjun6.png',
#   './dataset/the_cropped/allu_arjun\\allu_arjun7.png',
#   './dataset/the_cropped/allu_arjun\\allu_arjun8.png',
#   './dataset/the_cropped/allu_arjun\\allu_arjun9.png'],
#  'anushka_shetty': ['./dataset/the_cropped/anushka_shetty\\anushka_shetty1.png',
#   './dataset/the_cropped/anushka_shetty\\anushka_shetty2.png',
#   './dataset/the_cropped/anushka_shetty\\anushka_shetty3.png',
#   './dataset/the_cropped/anushka_shetty\\anushka_shetty4.png',
#   './dataset/the_cropped/anushka_shetty\\anushka_shetty5.png',
#   './dataset/the_cropped/anushka_shetty\\anushka_shetty6.png',
#   './dataset/the_cropped/anushka_shetty\\anushka_shetty7.png'],
#  'dhanush': ['./dataset/the_cropped/dhanush\\dhanush1.png',
#   './dataset/the_cropped/dhanush\\dhanush10.png',
#   './dataset/the_cropped/dhanush\\dhanush11.png',
#   './dataset/the_cropped/dhanush\\dhanush12.png',
#   './dataset/the_cropped/dhanush\\dhanush13.png',
#   './dataset/the_cropped/dhanush\\dhanush14.png',
#   './dataset/the_cropped/dhanush\\dhanush15.png',
#   './dataset/the_cropped/dhanush\\dhanush16.png',
#   './dataset/the_cropped/dhanush\\dhanush17.png',
#   './dataset/the_cropped/dhanush\\dhanush18.png',
#   './dataset/the_cropped/dhanush\\dhanush2.png',
#   './dataset/the_cropped/dhanush\\dhanush3.png',
#   './dataset/the_cropped/dhanush\\dhanush4.png',
#   './dataset/the_cropped/dhanush\\dhanush5.png',
#   './dataset/the_cropped/dhanush\\dhanush6.png',
#   './dataset/the_cropped/dhanush\\dhanush7.png',
#   './dataset/the_cropped/dhanush\\dhanush8.png',
#   './dataset/the_cropped/dhanush\\dhanush9.png'],
#  'jr_ntr': ['./dataset/the_cropped/jr_ntr\\jr_ntr1.png',
#   './dataset/the_cropped/jr_ntr\\jr_ntr10.png',
#   './dataset/the_cropped/jr_ntr\\jr_ntr11.png',
#   './dataset/the_cropped/jr_ntr\\jr_ntr12.png',
#   './dataset/the_cropped/jr_ntr\\jr_ntr13.png',
#   './dataset/the_cropped/jr_ntr\\jr_ntr14.png',
#   './dataset/the_cropped/jr_ntr\\jr_ntr15.png',
#   './dataset/the_cropped/jr_ntr\\jr_ntr16.png',
#   './dataset/the_cropped/jr_ntr\\jr_ntr17.png',
#   './dataset/the_cropped/jr_ntr\\jr_ntr2.png',
#   './dataset/the_cropped/jr_ntr\\jr_ntr3.png',
#   './dataset/the_cropped/jr_ntr\\jr_ntr4.png',
#   './dataset/the_cropped/jr_ntr\\jr_ntr5.png',
#   './dataset/the_cropped/jr_ntr\\jr_ntr6.png',
#   './dataset/the_cropped/jr_ntr\\jr_ntr7.png',
#   './dataset/the_cropped/jr_ntr\\jr_ntr8.png',
#   './dataset/the_cropped/jr_ntr\\jr_ntr9.png'],
#  'kajal_aggarwal': ['./dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal1.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal10.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal11.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal12.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal13.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal14.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal15.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal16.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal17.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal18.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal19.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal2.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal20.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal21.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal3.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal4.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal5.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal6.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal7.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal8.png',
#   './dataset/the_cropped/kajal_aggarwal\\kajal_aggarwal9.png'],
#  'prabhas_raju': ['./dataset/the_cropped/prabhas_raju\\prabhas_raju1.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju10.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju11.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju12.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju13.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju14.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju15.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju16.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju17.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju18.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju19.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju2.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju20.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju21.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju22.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju23.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju24.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju25.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju26.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju27.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju28.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju29.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju3.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju30.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju31.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju32.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju4.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju5.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju6.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju7.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju8.png',
#   './dataset/the_cropped/prabhas_raju\\prabhas_raju9.png'],
#  'sai_pallavi': ['./dataset/the_cropped/sai_pallavi\\sai_pallavi1.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi10.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi11.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi12.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi13.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi14.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi15.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi16.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi17.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi18.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi19.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi2.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi20.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi21.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi22.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi23.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi24.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi25.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi26.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi27.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi28.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi3.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi4.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi5.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi6.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi7.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi8.png',
#   './dataset/the_cropped/sai_pallavi\\sai_pallavi9.png'],
#  'salman_khan': ['./dataset/the_cropped/salman_khan\\salman_khan1.png',
#   './dataset/the_cropped/salman_khan\\salman_khan2.png',
#   './dataset/the_cropped/salman_khan\\salman_khan3.png',
#   './dataset/the_cropped/salman_khan\\salman_khan4.png',
#   './dataset/the_cropped/salman_khan\\salman_khan5.png',
#   './dataset/the_cropped/salman_khan\\salman_khan6.png',
#   './dataset/the_cropped/salman_khan\\salman_khan7.png',
#   './dataset/the_cropped/salman_khan\\salman_khan8.png'],
#  'samantha_rutuprabhu': ['./dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu1.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu10.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu11.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu12.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu13.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu14.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu15.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu16.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu17.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu18.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu19.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu2.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu20.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu21.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu22.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu23.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu24.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu25.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu26.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu27.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu28.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu29.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu3.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu30.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu31.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu32.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu33.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu34.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu35.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu36.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu37.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu38.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu39.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu4.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu40.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu41.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu42.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu5.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu6.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu7.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu8.png',
#   './dataset/the_cropped/samantha_rutuprabhu\\samantha_rutuprabhu9.png'],
#  'thalapathy_vijay': ['./dataset/the_cropped/thalapathy_vijay\\thalapathy_vijay1.png',
#   './dataset/the_cropped/thalapathy_vijay\\thalapathy_vijay10.png',
#   './dataset/the_cropped/thalapathy_vijay\\thalapathy_vijay11.png',
#   './dataset/the_cropped/thalapathy_vijay\\thalapathy_vijay12.png',
#   './dataset/the_cropped/thalapathy_vijay\\thalapathy_vijay13.png',
#   './dataset/the_cropped/thalapathy_vijay\\thalapathy_vijay14.png',
#   './dataset/the_cropped/thalapathy_vijay\\thalapathy_vijay15.png',
#   './dataset/the_cropped/thalapathy_vijay\\thalapathy_vijay16.png',
#   './dataset/the_cropped/thalapathy_vijay\\thalapathy_vijay2.png',
#   './dataset/the_cropped/thalapathy_vijay\\thalapathy_vijay3.png',
#   './dataset/the_cropped/thalapathy_vijay\\thalapathy_vijay4.png',
#   './dataset/the_cropped/thalapathy_vijay\\thalapathy_vijay5.png',
#   './dataset/the_cropped/thalapathy_vijay\\thalapathy_vijay6.png',
#   './dataset/the_cropped/thalapathy_vijay\\thalapathy_vijay7.png',
#   './dataset/the_cropped/thalapathy_vijay\\thalapathy_vijay8.png',
#   './dataset/the_cropped/thalapathy_vijay\\thalapathy_vijay9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'allu_arjun': 0,
#  'anushka_shetty': 1,
#  'dhanush': 2,
#  'jr_ntr': 3,
#  'kajal_aggarwal': 4,
#  'prabhas_raju': 5,
#  'sai_pallavi': 6,
#  'salman_khan': 7,
#  'samantha_rutuprabhu': 8,
#  'thalapathy_vijay': 9}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/233566380.py in <module>
#       4         img = cv2.imread(training_image)
#       5         scalled_raw_img = cv2.resize(img, (32, 32))
# ----> 6         img_har = w2d(img,'db1',5)
#       7         scalled_img_har = cv2.resize(img_har, (32, 32))
#       8         combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
#
# NameError: name 'w2d' is not defined

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])
